# %% [markdown]
# ### Joining Data From Previous Notebooks
# (the two files containing demographic & soccer activity/rent data)

# %% [markdown]
# ---

# %%
import pandas as pd
import numpy as np
import geopandas as gpd

# %%
demographics_LA_OC = pd.read_csv('demographics_LA_OC.csv')  # Only includes LA & OC cities

# %%
all_rent_activity_data = pd.read_csv('all_rent_activity_data.csv')  # Contains all map cities (including those not in LA or OC)

# %%
demographics_LA_OC.tail(1)
# Out:
#                City  Median_Age  Median_Income  Normalized_Income  \
# 112  Woodland Hills        37.0        27200.0               0.41
#
#      Male_Percent  Hispanic_Percent
# 112           0.5              0.31

# %%
all_rent_activity_data.tail(1)
# Out:
#               City  Avg Rent - Office  Avg Rent - Industrial  \
# 196  Jurupa Valley                0.0                    0.0
#
#      Avg Rent - Retail  Soccer_Activity
# 196                0.0              0.0

# %% [markdown]
# - Add rows w/ cities from all_rent_activity_data that aren't in demographics_LA_OC
# - Fill city col w/ cities not in demographics_LA_OC
# - Fill empty cells w/ avg. col values
# - Merge w/ all_rent_activity_data (to include rent/activity data)

# %%
for city in demographics_LA_OC.City:
    if city not in all_rent_activity_data.City.values:
        print(city)
# Out:
# Palos Verdes
# Woodland Hills

# %%
demographics_LA_OC = demographics_LA_OC[~demographics_LA_OC.City.isin(['Palos Verdes', 'Woodland Hills'])]

# %%
demographics_LA_OC.shape[0]
# Out:
# 111

# %%
missing = []
for city in all_rent_activity_data.City:
    if city not in demographics_LA_OC.City.values:
        missing.append(city)

# %%
missing_cities_df = pd.DataFrame(index=range(len(missing)), columns=demographics_LA_OC.columns)

# %%
missing_cities_df['City'] = missing

# %%
missing_cities_df.head(1)
# Out:
#                    City Median_Age Median_Income Normalized_Income  \
# 0  Palos Verdes Estates        NaN           NaN               NaN
#
#   Male_Percent Hispanic_Percent
# 0          NaN              NaN

# %%
all_rent_activity_data.tail()
# Out:
#                City  Avg Rent - Office  Avg Rent - Industrial  \
# 192  Unincorporated                0.0                    0.0
# 193    Palm Springs                0.0                    0.0
# 194  Unincorporated                0.0                    0.0
# 195         Banning                0.0                    0.0
# 196   Jurupa Valley                0.0                    0.0
#
#      Avg Rent - Retail  Soccer_Activity
# 192                0.0              0.0
# 193                0.0              0.0
# 194                0.0              0.0
# 195                0.0              0.0
# 196                0.0              0.0

# %%
for col in missing_cities_df.columns[1:]:
    missing_cities_df[col] = demographics_LA_OC[col].median()

# %%
missing_cities_df.head(1)
# Out:
#                    City  Median_Age  Median_Income  Normalized_Income  \
# 0  Palos Verdes Estates        39.0        23900.0               0.33
#
#    Male_Percent  Hispanic_Percent
# 0          0.49              0.32

# %%
combined = pd.concat([demographics_LA_OC, missing_cities_df]).reset_index(drop=True)

# %%
combined.tail()
# Out:
#                City  Median_Age  Median_Income  Normalized_Income  \
# 192  Unincorporated        39.0        23900.0               0.33
# 193    Palm Springs        39.0        23900.0               0.33
# 194  Unincorporated        39.0        23900.0               0.33
# 195         Banning        39.0        23900.0               0.33
# 196   Jurupa Valley        39.0        23900.0               0.33
#
#      Male_Percent  Hispanic_Percent
# 192          0.49              0.32
# 193          0.49              0.32
# 194          0.49              0.32
# 195          0.49              0.32
# 196          0.49              0.32

# %%
len(combined)
# Out:
# 197

# %%
len(all_rent_activity_data)
# Out:
# 197

# %%
combined_all = pd.merge(combined, all_rent_activity_data.loc[:,'Avg Rent - Office':], right_index=True, left_index=True)

# %%
len(combined_all)
# Out:
# 197

# %%
combined_all
# Out:
#                City  Median_Age  Median_Income  Normalized_Income  \
# 0       Aliso Viejo        46.0        40000.0               0.76
# 1           Anaheim        34.0        20000.0               0.22
# 2              Brea        39.0        31800.0               0.54
# 3        Buena Park        41.0        24000.0               0.33
# 4        Costa Mesa        36.0        30000.0               0.49
# ..              ...         ...            ...                ...
# 192  Unincorporated        39.0        23900.0               0.33
# 193    Palm Springs        39.0        23900.0               0.33
# 194  Unincorporated        39.0        23900.0               0.33
# 195         Banning        39.0        23900.0               0.33
# 196   Jurupa Valley        39.0        23900.0               0.33
#
#      Male_Percent  Hispanic_Percent  Avg Rent - Office  Avg Rent - Industrial  \
# 0            0.47              0.14               0.00                   0.00
# 1            0.51              0.55              20.55                  11.91
# 2            0.50              0.34              22.87                   9.59
# 3            0.49              0.28               0.00                   0.00
# 4            0.50              0.28              23.33                   0.00
# ..            ...               ...                ...                    ...
# 192          0.49              0.32               0.00                   0.00
# 193          0.49              0.32               0.00                   0.00
# 194          0.49              0.32               0.00                   0.00
# 195          0.49              0.32               0.00                   0.00
# 196          0.49              0.32               0.00                   0.00
#
#      Avg Rent - Retail  Soccer_Activity
# 0                 0.00              0.0
# 1                21.82              2.0
# 2                 0.00              2.0
# 3                 0.00              0.0
# 4                27.01              1.0
# ..                 ...              ...
# 192               0.00              0.0
# 193               0.00              0.0
# 194               0.00              0.0
# 195               0.00              0.0
# 196               0.00              0.0
#
# [197 rows x 10 columns]

# %%
combined_all.to_csv('combined_all.csv', index=False)

# %% [markdown]
# *The columns in this combined df will be joined w/ the mapping shapefile in QGIS

# %% [markdown]
# ---
