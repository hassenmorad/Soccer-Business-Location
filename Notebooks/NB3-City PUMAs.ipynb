# %% [markdown]
# ### Linking Cities with PUMA Codes

# %% [markdown]
# (PUMA is a US Census geographic unit; this file created in this notebook will be used to link cities to Census demographics in NB4)

# %% [markdown]
# ---

# %%
import pandas as pd

# %%
rent_and_activity_data = pd.read_csv('rent_and_activity_data.csv')  # Only includes So Cal cities in LA & Orange counties (from NB1)

# %%
len(rent_and_activity_data)
# Out:
# 113

# %% [markdown]
# ### Examining PUMA Data

# %%
# Source: https://usa.ipums.org/usa/volii/cpuma0010.shtml
# PUMA description: https://usa.ipums.org/usa-action/variables/PUMA#description_section
pumas_df = pd.read_csv('PUMA2000_PUMA2010_crosswalk.csv')

# %%
pumas_df.head(1)
# Out:
#    State00  PUMA00  GEOID00  GISJOIN00  State10  PUMA10  GEOID10  GISJOIN10  \
# 0        1     100   100100  G01000100        1     100   100100  G01000100
#
#   State10_Name                                        PUMA10_Name  ...  \
# 0      Alabama  Lauderdale, Colbert, Franklin & Marion (Northe...  ...
#
#    PUMA00_Pop10  PUMA10_Pop10 Part_Pop10 pPUMA00_Pop10 pPUMA10_Pop10  \
# 0       147,137       186,695    147,137         100.0         78.81
#
#      PUMA00_Land    PUMA10_Land      Part_Land pPUMA00_Land pPUMA10_Land
# 0  3,264,203,919  5,400,949,424  3,264,203,919        100.0        60.44
#
# [1 rows x 27 columns]

# %%
pumas_df.columns
# Out:
# Index(['State00', 'PUMA00', 'GEOID00', 'GISJOIN00', 'State10', 'PUMA10',
#        'GEOID10', 'GISJOIN10', 'State10_Name', 'PUMA10_Name', 'CPUMA00',
#        'CPUMA10', 'PUMA00_Pop00', 'PUMA10_Pop00', 'Part_Pop00',
#        'pPUMA00_Pop00', 'pPUMA10_Pop00', 'PUMA00_Pop10', 'PUMA10_Pop10',
#        'Part_Pop10', 'pPUMA00_Pop10', 'pPUMA10_Pop10', 'PUMA00_Land',
#        'PUMA10_Land', 'Part_Land', 'pPUMA00_Land', 'pPUMA10_Land'],
#       dtype='object')

# %%
# The first two PUMA digits correspond to county (which I'll use to filter the data below)
pumas_df['County'] = pumas_df.PUMA10.astype(str).apply(lambda x:x[:2]).astype(int)

# %%
puma_cols = ['State10', 'State10_Name', 'PUMA10', 'County', 'PUMA10_Name', 'PUMA10_Pop10', 'PUMA10_Land']

# %%
# Including only LA & OC PUMAs
pumas_df = pumas_df[puma_cols][(pumas_df.State10 == 6) & (pumas_df.County.isin([37, 59]))].sort_values('PUMA10')

# %%
# To reveal all data in each cell (instead of cutting off at default max character length)
pd.set_option('display.max_colwidth', -1)

# %%
pumas_df.head()
# Out:
#      State10 State10_Name  PUMA10  County  \
# 588  6        California   3701    37
# 855  6        California   3701    37
# 690  6        California   3701    37
# 993  6        California   3701    37
# 999  6        California   3701    37
#
#                                             PUMA10_Name PUMA10_Pop10  \
# 588  Los Angeles County (North/Unincorporated)--Castaic  139,801
# 855  Los Angeles County (North/Unincorporated)--Castaic  139,801
# 690  Los Angeles County (North/Unincorporated)--Castaic  139,801
# 993  Los Angeles County (North/Unincorporated)--Castaic  139,801
# 999  Los Angeles County (North/Unincorporated)--Castaic  139,801
#
#        PUMA10_Land
# 588  5,446,091,332
# 855  5,446,091,332
# 690  5,446,091,332
# 993  5,446,091,332
# 999  5,446,091,332

# %%
pumas_df = pumas_df.drop_duplicates().reset_index(drop=True)

# %%
pumas_df.head()
# Out:
#    State10 State10_Name  PUMA10  County  \
# 0  6        California   3701    37
# 1  6        California   3702    37
# 2  6        California   3703    37
# 3  6        California   3704    37
# 4  6        California   3705    37
#
#                                                                  PUMA10_Name  \
# 0  Los Angeles County (North/Unincorporated)--Castaic
# 1  Los Angeles County (Northwest)--Santa Clarita City
# 2  Los Angeles County (North Central)--Lancaster City
# 3  Los Angeles County (North Central)--Palmdale City
# 4  Los Angeles County (North)--LA City (Northwest/Chatsworth & Porter Ranch)
#
#   PUMA10_Pop10    PUMA10_Land
# 0  139,801      5,446,091,332
# 1  188,102      161,374,066
# 2  163,632      368,397,749
# 3  164,268      330,295,975
# 4  166,932      95,429,064

# %% [markdown]
# ---

# %% [markdown]
# Examining city naming format:

# %%
for city_name in pumas_df.PUMA10_Name.apply(lambda x:x.split('--').pop(1)):
    print(city_name)
# Out:
# Castaic
# Santa Clarita City
# Lancaster City
# Palmdale City
# LA City (Northwest/Chatsworth & Porter Ranch)
# LA City (North Central/Granada Hills & Sylmar)
# LA (North Central/Arleta & Pacoima) & San Fernando Cities
# LA City (Northeast/Sunland, Sun Valley & Tujunga)
# San Gabriel Valley Region (North)
# Baldwin Park, Azusa, Duarte & Irwindale Cities
# Glendora, Claremont, San Dimas & La Verne Cities
# Pomona City
# Covina & Walnut Cities
# Diamond Bar, La Habra Heights (East) Cities & Rowland Heights
# West Covina City
# La Puente & Industry Cities
# Arcadia, San Gabriel & Temple City Cities
# Pasadena City
# Glendale City
# Burbank City
# LA City (Northeast/North Hollywood & Valley Village)
# LA City (North Central/Van Nuys & North Sherman Oaks)
# LA City (North Central/Mission Hills & Panorama City)
# LA City (Northwest/Encino & Tarzana)
# LA City (Northwest/Canoga Park, Winnetka & Woodland Hills)
# Calabasas, Agoura Hills, Malibu & Westlake Village Cities
# LA City (Central/Pacific Palisades)
# Santa Monica City
# LA City (West Central/Westwood & West Los Angeles)
# LA City (Central/Hancock Park & Mid-Wilshire)
# West Hollywood & Beverly Hills Cities
# LA City (East Central/Hollywood)
# LA City (Central/Koreatown)
# LA City (East Central/Silver Lake, Echo Park & Westlake)
# LA City (Mount Washington, Highland Park & Glassell Park)
# Alhambra & South Pasadena Cities
# Monterey Park & Rosemead Cities
# El Monte & South El Monte Cities
# Whittier City & Hacienda Heights
# Pico Rivera & Montebello Cities
# Bell Gardens, Bell, Maywood, Cudahy & Commerce Cities
# Huntington Park City, Florence-Graham & Walnut Park
# East Los Angeles
# LA City (East Central/Central City & Boyle Heights)
# LA City (Southeast/East Vernon)
# LA City (Central/Univ. of Southern California & Exposition Park)
# LA City (Central/West Adams & Baldwin Hills)
# LA (Southwest/Marina del Rey & Westchester) & Culver City Cities
# Inglewood City
# LA City (South Central/Westmont)
# LA City (South Central/Watts)
# South Gate & Lynwood Cities
# Downey City
# La Mirada & Santa Fe Springs Cities
# Norwalk City
# Bellflower & Paramount Cities
# Compton City & West Rancho Dominguez
# Gardena, Lawndale Cities & West Athens
# Hawthorne City
# Redondo Beach, Manhattan Beach & Hermosa Beach Cities
# Torrance City
# Carson City
# Long Beach City (North)
# Lakewood, Cerritos, Artesia & Hawaiian Gardens Cities
# Long Beach City (East)
# Long Beach City (Southwest & Port)
# LA City (South/San Pedro)
# Palos Verdes Peninsula
# Long Beach (Central) & Signal Hill Cities
# San Clemente, Laguna Niguel & San Juan Capistrano Cities
# Mission Viejo & Rancho Santa Margarita (West) Cities
# Newport Beach, Aliso Viejo & Laguna Hills Cities
# Irvine City (Central)
# Lake Forest, Irvine (North) Cities & Silverado
# Yorba Linda, La Habra & Brea Cities
# Fullerton & Placentia Cities
# Buena Park, Cypress & Seal Beach Cities
# Anaheim City (West)
# Anaheim City (East)
# Orange & Villa Park Cities
# Westminster, Stanton & Garden Grove (West) Cities
# Garden Grove City (East)
# Huntington Beach City
# Rancho Santa Margarita City (East) & Ladera Ranch
# Santa Ana City (West)
# Santa Ana City (East)
# Costa Mesa & Fountain Valley Cities

# %% [markdown]
# ---

# %% [markdown]
# Observations:
# - Some cities are located in multiple PUMAs
# - Los Angeles City is listed as "LA City"

# %% [markdown]
# ---

# %% [markdown]
# Linking PUMA Codes to Corresponding City Names (in rent_and_activity_data):

# %%
len(pumas_df)
# Out:
# 87

# %%
len(rent_and_activity_data.City)
# Out:
# 113

# %%
# Extracting PUMA(s) corresponding to each city in 'all_rent_activity_data'
city_pumas_dict = {}
missing_pumas = []
counter = 1

for city in rent_and_activity_data.City:
    if city == 'Los Angeles':
        df = pumas_df[pumas_df.PUMA10_Name.str.contains('LA City')]  # To distinguish it from LA County
    elif city == 'Orange':
        df = pumas_df[pumas_df.PUMA10_Name.str.contains('Orange & Villa Park')]  # To distinguish it from Orange County
    else:
        df = pumas_df[pumas_df.PUMA10_Name.str.contains(city)] 
    
    if len(df) == 0:  # i.e. no PUMA corresponding to city in 'combined' df
        missing_pumas.append(city)
        city_pumas_dict[city] = []
    else:
        city_pumas_dict[city] = list(df.PUMA10.values)

# %%
len(city_pumas_dict)
# Out:
# 113

# %%
city_pumas_dict
# Out:
# {'Aliso Viejo': [5903],
#  'Anaheim': [5909, 5910],
#  'Brea': [5906],
#  'Buena Park': [5908],
#  'Costa Mesa': [5918],
#  'Cypress': [5908],
#  'Dana Point': [],
#  'Fountain Valley': [5918],
#  'Fullerton': [5907],
#  'Garden Grove': [5912, 5913],
#  'Huntington Beach': [5914],
#  'Irvine': [5904, 5905],
#  'La Habra': [3714, 5906],
#  'La Palma': [],
#  'Laguna Beach': [],
#  'Laguna Hills': [5903],
#  'Laguna Niguel': [5901],
#  'Laguna Woods': [],
#  'Lake Forest': [5905],
#  'Los Alamitos': [],
#  'Mission Viejo': [5902],
#  'Newport Beach': [5903],
#  'Orange': [5911],
#  'Placentia': [5907],
#  'Rancho Santa Margarita': [5902, 5915],
#  'San Clemente': [5901],
#  'San Juan Capistrano': [5901],
#  'Santa Ana': [5916, 5917],
#  'Seal Beach': [5908],
#  'Stanton': [5912],
#  'Tustin': [],
#  'Westminster': [5912],
#  'Yorba Linda': [5906],
#  'Agoura Hills': [3726],
#  'Alhambra': [3736],
#  'Arcadia': [3717],
#  'Artesia': [3764],
#  'Avalon': [],
#  'Azusa': [3710],
#  'Baldwin Park': [3710],
#  'Bell Gardens': [3741],
#  'Bellflower': [3756],
#  'Beverly Hills': [3731],
#  'Burbank': [3720],
#  'Calabasas': [3726],
#  'Carson': [3762],
#  'Cerritos': [3764],
#  'Claremont': [3711],
#  'Commerce': [3741],
#  'Compton': [3757],
#  'Covina': [3713, 3715],
#  'Culver City': [3748],
#  'Diamond Bar': [3714],
#  'Downey': [3753],
#  'Duarte': [3710],
#  'El Monte': [3738],
#  'El Segundo': [],
#  'Gardena': [3758],
#  'Glendale': [3719],
#  'Glendora': [3711],
#  'Hawaiian Gardens': [3764],
#  'Hawthorne': [3759],
#  'Hermosa Beach': [3760],
#  'Huntington Park': [3742],
#  'Industry': [3716],
#  'Inglewood': [3749],
#  'Irwindale': [3710],
#  'La Canada Flintridge': [],
#  'La Mirada': [3754],
#  'La Puente': [3716],
#  'La Verne': [3711],
#  'La Habra Heights': [3714],
#  'Lakewood': [3764],
#  'Lancaster': [3703],
#  'Lawndale': [3758],
#  'Lomita': [],
#  'Long Beach': [3763, 3765, 3766, 3769],
#  'Los Angeles': [3705,
#   3706,
#   3708,
#   3721,
#   3722,
#   3723,
#   3724,
#   3725,
#   3727,
#   3729,
#   3730,
#   3732,
#   3733,
#   3734,
#   3735,
#   3744,
#   3745,
#   3746,
#   3747,
#   3750,
#   3751,
#   3767],
#  'Lynwood': [3752],
#  'Malibu': [3726],
#  'Manhattan Beach': [3760],
#  'Monrovia': [],
#  'Montebello': [3740],
#  'Monterey Park': [3737],
#  'Norwalk': [3755],
#  'Palmdale': [3704],
#  'Palos Verdes': [3768],
#  'Paramount': [3756],
#  'Pasadena': [3718, 3736],
#  'Pico Rivera': [3740],
#  'Pomona': [3712],
#  'Redondo Beach': [3760],
#  'Rosemead': [3737],
#  'San Dimas': [3711],
#  'San Fernando': [3707],
#  'San Gabriel': [3709, 3717],
#  'San Marino': [],
#  'Santa Clarita': [3702],
#  'Santa Fe Springs': [3754],
#  'Santa Monica': [3728],
#  'Signal Hill': [3769],
#  'South El Monte': [3738],
#  'South Gate': [3752],
#  'South Pasadena': [3736],
#  'Temple City': [3717],
#  'Torrance': [3761],
#  'Vernon': [3745],
#  'Walnut': [3713, 3742],
#  'West Covina': [3715],
#  'West Hollywood': [3731],
#  'Westlake Village': [3726],
#  'Whittier': [3739],
#  'Woodland Hills': [3725]}

# %%
# Cities w/ no corresponding PUMA
missing_pumas
# Out:
# ['Dana Point',
#  'La Palma',
#  'Laguna Beach',
#  'Laguna Woods',
#  'Los Alamitos',
#  'Tustin',
#  'Avalon',
#  'El Segundo',
#  'La Canada Flintridge',
#  'Lomita',
#  'Monrovia',
#  'San Marino']

# %%
# Manually assigned PUMA value of a comparable bordering city that is included in pumas_df 
missing_pumas_dict = {
    'Dana Point':['Laguna Niguel'],
    'La Palma':['Cerritos'],
    'Laguna Beach':['Laguna Niguel'],
    'Laguna Woods':['Laguna Niguel'],
    'Los Alamitos':['Cypress'],
    'Tustin':['Irvine'],
    'Avalon':['Newport Beach'],
    'El Segundo':['Hawthorne'],
    'La Canada Flintridge':['Glendale'],
    'Lomita':['Torrance'],
    'Monrovia':['Arcadia'],
    'San Marino':['San Gabriel']
}

# %% [markdown]
# ---

# %% [markdown]
# Assigning PUMA values to cities w/ missing PUMAs:

# %%
for key in missing_pumas_dict:
    pumas = []
    for city in missing_pumas_dict[key]:
        pumas = list(pumas_df.PUMA10[pumas_df.PUMA10_Name.str.contains(city)].values)
    city_pumas_dict[key] = pumas

# %%
city_pumas_dict
# Out:
# {'Aliso Viejo': [5903],
#  'Anaheim': [5909, 5910],
#  'Brea': [5906],
#  'Buena Park': [5908],
#  'Costa Mesa': [5918],
#  'Cypress': [5908],
#  'Dana Point': [5901],
#  'Fountain Valley': [5918],
#  'Fullerton': [5907],
#  'Garden Grove': [5912, 5913],
#  'Huntington Beach': [5914],
#  'Irvine': [5904, 5905],
#  'La Habra': [3714, 5906],
#  'La Palma': [3764],
#  'Laguna Beach': [5901],
#  'Laguna Hills': [5903],
#  'Laguna Niguel': [5901],
#  'Laguna Woods': [5901],
#  'Lake Forest': [5905],
#  'Los Alamitos': [5908],
#  'Mission Viejo': [5902],
#  'Newport Beach': [5903],
#  'Orange': [5911],
#  'Placentia': [5907],
#  'Rancho Santa Margarita': [5902, 5915],
#  'San Clemente': [5901],
#  'San Juan Capistrano': [5901],
#  'Santa Ana': [5916, 5917],
#  'Seal Beach': [5908],
#  'Stanton': [5912],
#  'Tustin': [5904, 5905],
#  'Westminster': [5912],
#  'Yorba Linda': [5906],
#  'Agoura Hills': [3726],
#  'Alhambra': [3736],
#  'Arcadia': [3717],
#  'Artesia': [3764],
#  'Avalon': [5903],
#  'Azusa': [3710],
#  'Baldwin Park': [3710],
#  'Bell Gardens': [3741],
#  'Bellflower': [3756],
#  'Beverly Hills': [3731],
#  'Burbank': [3720],
#  'Calabasas': [3726],
#  'Carson': [3762],
#  'Cerritos': [3764],
#  'Claremont': [3711],
#  'Commerce': [3741],
#  'Compton': [3757],
#  'Covina': [3713, 3715],
#  'Culver City': [3748],
#  'Diamond Bar': [3714],
#  'Downey': [3753],
#  'Duarte': [3710],
#  'El Monte': [3738],
#  'El Segundo': [3759],
#  'Gardena': [3758],
#  'Glendale': [3719],
#  'Glendora': [3711],
#  'Hawaiian Gardens': [3764],
#  'Hawthorne': [3759],
#  'Hermosa Beach': [3760],
#  'Huntington Park': [3742],
#  'Industry': [3716],
#  'Inglewood': [3749],
#  'Irwindale': [3710],
#  'La Canada Flintridge': [3719],
#  'La Mirada': [3754],
#  'La Puente': [3716],
#  'La Verne': [3711],
#  'La Habra Heights': [3714],
#  'Lakewood': [3764],
#  'Lancaster': [3703],
#  'Lawndale': [3758],
#  'Lomita': [3761],
#  'Long Beach': [3763, 3765, 3766, 3769],
#  'Los Angeles': [3705,
#   3706,
#   3708,
#   3721,
#   3722,
#   3723,
#   3724,
#   3725,
#   3727,
#   3729,
#   3730,
#   3732,
#   3733,
#   3734,
#   3735,
#   3744,
#   3745,
#   3746,
#   3747,
#   3750,
#   3751,
#   3767],
#  'Lynwood': [3752],
#  'Malibu': [3726],
#  'Manhattan Beach': [3760],
#  'Monrovia': [3717],
#  'Montebello': [3740],
#  'Monterey Park': [3737],
#  'Norwalk': [3755],
#  'Palmdale': [3704],
#  'Palos Verdes': [3768],
#  'Paramount': [3756],
#  'Pasadena': [3718, 3736],
#  'Pico Rivera': [3740],
#  'Pomona': [3712],
#  'Redondo Beach': [3760],
#  'Rosemead': [3737],
#  'San Dimas': [3711],
#  'San Fernando': [3707],
#  'San Gabriel': [3709, 3717],
#  'San Marino': [3709, 3717],
#  'Santa Clarita': [3702],
#  'Santa Fe Springs': [3754],
#  'Santa Monica': [3728],
#  'Signal Hill': [3769],
#  'South El Monte': [3738],
#  'South Gate': [3752],
#  'South Pasadena': [3736],
#  'Temple City': [3717],
#  'Torrance': [3761],
#  'Vernon': [3745],
#  'Walnut': [3713, 3742],
#  'West Covina': [3715],
#  'West Hollywood': [3731],
#  'Westlake Village': [3726],
#  'Whittier': [3739],
#  'Woodland Hills': [3725]}

# %%
city_pumas = pd.DataFrame(list(city_pumas_dict.items()), columns=['City', 'PUMAs'])

# %%
city_pumas
# Out:
#                  City         PUMAs
# 0    Aliso Viejo       [5903]
# 1    Anaheim           [5909, 5910]
# 2    Brea              [5906]
# 3    Buena Park        [5908]
# 4    Costa Mesa        [5918]
# ..          ...           ...
# 108  West Covina       [3715]
# 109  West Hollywood    [3731]
# 110  Westlake Village  [3726]
# 111  Whittier          [3739]
# 112  Woodland Hills    [3725]
#
# [113 rows x 2 columns]

# %%
len(city_pumas)
# Out:
# 113

# %%
city_pumas.to_csv('city_pumas.csv', index=False)

# %% [markdown]
# ---
